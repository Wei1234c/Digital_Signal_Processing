# %% [markdown]
# # Music notes and frequency distribution
# https://www.thedaobums.com/topic/43213-where-is-the-music/?page=2
# https://en.wikipedia.org/wiki/Spiral_array_model
# http://www.spiralmusic.org/en/general/theory/patent_spiral_audio_spectrum_display_system

# %%
# %pylab inline

# import numpy as np
# import matplotlib
# matplotlib.use('Qt5Agg')
# import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

import os
import sys 

path = 'C:\\Users\\Wei\\Dropbox\\Coding\\notebooks\\專案\\待處理\\Waves\\bitbucket\\github\\codes'
path = '/home/wei/Dropbox/Coding/notebooks/專案/待處理/Waves/bitbucket/github/codes'
sys.path.append(path)

from waves.sound.tools.music import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
semitones = list('CDEFGAB')
# octaves = range(1, 7)
octaves = range(9)
accs = ['b', '', '#']

# %%
notes, freqs, freqs_notes = MusicNote.gen_notes(semitones, octaves, accs = None)
# freqs_notes

# %%
notes
# Out:
# array(['C0', 'D0', 'E0', 'F0', 'G0', 'A0', 'B0', 'C1', 'D1', 'E1', 'F1',
#        'G1', 'A1', 'B1', 'C2', 'D2', 'E2', 'F2', 'G2', 'A2', 'B2', 'C3',
#        'D3', 'E3', 'F3', 'G3', 'A3', 'B3', 'C4', 'D4', 'E4', 'F4', 'G4',
#        'A4', 'B4', 'C5', 'D5', 'E5', 'F5', 'G5', 'A5', 'B5', 'C6', 'D6',
#        'E6', 'F6', 'G6', 'A6', 'B6', 'C7', 'D7', 'E7', 'F7', 'G7', 'A7',
#        'B7', 'C8', 'D8', 'E8', 'F8', 'G8', 'A8', 'B8'], dtype='<U32')

# %%
freqs
# Out:
# array([  16.35,   18.35,   20.6 ,   21.83,   24.5 ,   27.5 ,   30.87,
#          32.7 ,   36.71,   41.2 ,   43.65,   49.  ,   55.  ,   61.74,
#          65.41,   73.42,   82.41,   87.31,   98.  ,  110.  ,  123.47,
#         130.81,  146.83,  164.81,  174.61,  196.  ,  220.  ,  246.94,
#         261.63,  293.66,  329.63,  349.23,  392.  ,  440.  ,  493.88,
#         523.25,  587.33,  659.26,  698.46,  783.99,  880.  ,  987.77,
#        1046.5 , 1174.66, 1318.51, 1396.91, 1567.98, 1760.  , 1975.53,
#        2093.  , 2349.32, 2637.02, 2793.83, 3135.96, 3520.  , 3951.07,
#        4186.01, 4698.64, 5274.04, 5587.65, 6271.93, 7040.  , 7902.13])

# %%
plt.plot(notes, np.log2(freqs))
plt.xticks(rotation = 90);

# %%
x = range(len(semitones))
y = octaves
X, Y = np.meshgrid(x, y)
Z = np.log2(freqs).reshape(X.shape)

# %%
fig = plt.figure(figsize = (8, 6))
ax = fig.add_subplot(1, 1, 1, projection='3d')

ax.plot_surface(X, Y, Z, cmap = cm.coolwarm, linewidth = 0, antialiased = True)
plt.xticks(x, semitones);
